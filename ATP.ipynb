# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/pratheerthpadman/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
atp_2000 = pd.read_csv("atp_matches_2000.csv")
atp_2001 = pd.read_csv("atp_matches_2001.csv")
atp_2002 = pd.read_csv("atp_matches_2002.csv")
atp_2003 = pd.read_csv("atp_matches_2003.csv")
atp_2004 = pd.read_csv("atp_matches_2004.csv")
atp_2005 = pd.read_csv("atp_matches_2005.csv")
atp_2006 = pd.read_csv("atp_matches_2006.csv")
atp_2007 = pd.read_csv("atp_matches_2007.csv")
atp_2008 = pd.read_csv("atp_matches_2008.csv")
atp_2009 = pd.read_csv("atp_matches_2009.csv")
atp_2010 = pd.read_csv("atp_matches_2010.csv")
atp_2011 = pd.read_csv("atp_matches_2011.csv")
atp_2012 = pd.read_csv("atp_matches_2012.csv")
atp_2013 = pd.read_csv("atp_matches_2013.csv")
atp_2014 = pd.read_csv("atp_matches_2014.csv")
atp_2015 = pd.read_csv("atp_matches_2015.csv")

# %%
test =

# %%
col_names = list(atp_2000.columns)

# %%
atp_2016 = pd.read_csv("atp_matches_2016.csv", header=0, usecols=col_names)
atp_2017 = pd.read_csv("atp_matches_2017.csv", header=0, usecols=col_names)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Loaded all the datasets into individual variables. The last two csv files seemed to be using the first 15 columns as index and needed a little bit of sorting around.

# %%
tennis = pd.concat([atp_2000, atp_2001, atp_2002, atp_2003, atp_2004, atp_2005, atp_2006, atp_2007, 
                   atp_2008, atp_2009, atp_2010, atp_2011, atp_2012, atp_2013, atp_2014, atp_2016, 
                   atp_2017], axis=0, ignore_index=True)

# %%
tennis
# Out:
#                            tourney_id                 tourney_name surface  \
# 0                            2000-717                      Orlando    Clay
# 1                            2000-717                      Orlando    Clay
# 2                            2000-717                      Orlando    Clay
# 3                            2000-717                      Orlando    Clay
# 4                            2000-717                      Orlando    Clay
# 5                            2000-717                      Orlando    Clay
# 6                            2000-717                      Orlando    Clay
# 7                            2000-717                      Orlando    Clay
# 8                            2000-717                      Orlando    Clay
# 9                            2000-717                      Orlando    Clay
# 10                           2000-717                      Orlando    Clay
# ...
